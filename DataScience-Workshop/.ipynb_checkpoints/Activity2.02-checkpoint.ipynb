# %% [markdown]
# # Activity 2.02: Fitting a Multiple Log-Linear Regression Model

# %%
#2
# %matplotlib inline
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.graphics.api as smg 
import pandas as pd
import numpy as np
import patsy
from statsmodels.graphics.correlation import plot_corr
from sklearn.model_selection import train_test_split
plt.style.use('seaborn')

# %%
#3 load dataset into dataframe
rawBostonData = pd.read_csv('Boston.csv')

# %%
#4 inspect first 5 rows of dataframe
rawBostonData.head()
# Out:
#       CRIM   ZN   INDUS   CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0    2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0    7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0    7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0    2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0    2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
#5 drop null values
rawBostonData = rawBostonData.dropna()

# %%
#6 check for duplicate records
rawBostonData = rawBostonData.drop_duplicates()

# %%
#7 list the column names of the dataframe
rawBostonData.columns
# Out:
# Index(['CRIM', ' ZN ', 'INDUS ', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
#8 rename column names to something meaningful
renamedBostonData = rawBostonData.rename(columns={'CRIM':'crimeRatePerCapita', ' ZN ':'landOver25k_sqft', 'INDUS ':'nonRetailLandProptn', 'CHAS':'riverDummy', 'NOX':'nitrixOxide_pp10m', 'RM':'AvgNo.RoomsPerDwelling', 'AGE': 'ProptnOwnerOccupied', 'DIS':'weightedDist', 'RAD':'radialHighwayAccess','TAX':'propTaxRate_per10k', 'PTRATIO':'pupilTeacherRatio', 'LSTAT':'pctLowerStatus', 'MEDV':'medianValue_Ks'})

# %%
renamedBostonData
# Out:
#      crimeRatePerCapita  landOver25k_sqft  nonRetailLandProptn  riverDummy  \
# 0               0.00632              18.0                 2.31           0
# 1               0.02731               0.0                 7.07           0
# 2               0.02729               0.0                 7.07           0
# 3               0.03237               0.0                 2.18           0
# 4               0.06905               0.0                 2.18           0
# ..                  ...               ...                  ...         ...
# 501             0.06263               0.0                11.93           0
# 502             0.04527               0.0                11.93           0
# 503             0.06076               0.0                11.93           0
# 504             0.10959               0.0                11.93           0
# 505             0.04741               0.0                11.93           0
#
#      nitrixOxide_pp10m  AvgNo.RoomsPerDwelling  ProptnOwnerOccupied  \
# 0                0.538                   6.575                 65.2
# 1                0.469                   6.421                 78.9
# 2                0.469                   7.185                 61.1
# 3                0.458                   6.998                 45.8
# 4                0.458                   7.147                 54.2
# ..                 ...                     ...                  ...
# 501              0.573                   6.593                 69.1
# 502              0.573                   6.120                 76.7
# 503              0.573                   6.976                 91.0
# 504              0.573                   6.794                 89.3
# 505              0.573                   6.030                 80.8
#
#      weightedDist  radialHighwayAccess  propTaxRate_per10k  pupilTeacherRatio  \
# 0          4.0900                    1                 296               15.3
# 1          4.9671                    2                 242               17.8
# 2          4.9671                    2                 242               17.8
# 3          6.0622                    3                 222               18.7
# 4          6.0622                    3                 222               18.7
# ..            ...                  ...                 ...                ...
# 501        2.4786                    1                 273               21.0
# 502        2.2875                    1                 273               21.0
# 503        2.1675                    1                 273               21.0
# 504        2.3889                    1                 273               21.0
# 505        2.5050                    1                 273               21.0
#
#      pctLowerStatus  medianValue_Ks
# 0              4.98            24.0
# 1              9.14            21.6
# 2              4.03            34.7
# 3              2.94            33.4
# 4              5.33            36.2
# ..              ...             ...
# 501            9.67            22.4
# 502            9.08            20.6
# 503            5.64            23.9
# 504            6.48            22.0
# 505            7.88            11.9
#
# [506 rows x 13 columns]

# %%
#9 inspect the data types of the colums
renamedBostonData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   crimeRatePerCapita      506 non-null    float64
#  1   landOver25k_sqft        506 non-null    float64
#  2   nonRetailLandProptn     506 non-null    float64
#  3   riverDummy              506 non-null    int64
#  4   nitrixOxide_pp10m       506 non-null    float64
#  5   AvgNo.RoomsPerDwelling  506 non-null    float64
#  6   ProptnOwnerOccupied     506 non-null    float64
#  7   weightedDist            506 non-null    float64
#  8   radialHighwayAccess     506 non-null    int64
#  9   propTaxRate_per10k      506 non-null    int64
#  10  pupilTeacherRatio       506 non-null    float64
#  11  pctLowerStatus          506 non-null    float64
#  12  medianValue_Ks          506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 55.3 KB

# %%
#10 calculate basic stats for numeric columns in dataframe
renamedBostonData.describe(include=[np.number]).T

# .T transposes the output of describe function to get better layout
# Out:
#                         count        mean         std        min         25%  \
# crimeRatePerCapita      506.0    3.613524    8.601545    0.00632    0.082045
# landOver25k_sqft        506.0   11.363636   23.322453    0.00000    0.000000
# nonRetailLandProptn     506.0   11.136779    6.860353    0.46000    5.190000
# riverDummy              506.0    0.069170    0.253994    0.00000    0.000000
# nitrixOxide_pp10m       506.0    0.554695    0.115878    0.38500    0.449000
# AvgNo.RoomsPerDwelling  506.0    6.284634    0.702617    3.56100    5.885500
# ProptnOwnerOccupied     506.0   68.574901   28.148861    2.90000   45.025000
# weightedDist            506.0    3.795043    2.105710    1.12960    2.100175
# radialHighwayAccess     506.0    9.549407    8.707259    1.00000    4.000000
# propTaxRate_per10k      506.0  408.237154  168.537116  187.00000  279.000000
# pupilTeacherRatio       506.0   18.455534    2.164946   12.60000   17.400000
# pctLowerStatus          506.0   12.653063    7.141062    1.73000    6.950000
# medianValue_Ks          506.0   22.532806    9.197104    5.00000   17.025000
#
#                               50%         75%       max
# crimeRatePerCapita        0.25651    3.677082   88.9762
# landOver25k_sqft          0.00000   12.500000  100.0000
# nonRetailLandProptn       9.69000   18.100000   27.7400
# riverDummy                0.00000    0.000000    1.0000
# nitrixOxide_pp10m         0.53800    0.624000    0.8710
# AvgNo.RoomsPerDwelling    6.20850    6.623500    8.7800
# ProptnOwnerOccupied      77.50000   94.075000  100.0000
# weightedDist              3.20745    5.188425   12.1265
# radialHighwayAccess       5.00000   24.000000   24.0000
# propTaxRate_per10k      330.00000  666.000000  711.0000
# pupilTeacherRatio        19.05000   20.200000   22.0000
# pctLowerStatus           11.36000   16.955000   37.9700
# medianValue_Ks           21.20000   25.000000   50.0000

# %%
#11 divide the dataset into training and test sets; train the dataset(s)
X = renamedBostonData.drop('crimeRatePerCapita', axis=1)
y = renamedBostonData[['crimeRatePerCapita']]
seed = 10
test_data_size = 0.3
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=test_data_size,random_state=seed)
train_data = pd.concat([X_train,y_train], axis=1)
test_data = pd.concat([X_test,y_test], axis=1)

# %%
# correlation matrix of on renamedBostonData
corrMatrix = renamedBostonData.corr(method='pearson')
corrMatrix
# Out:
#                         crimeRatePerCapita  landOver25k_sqft  \
# crimeRatePerCapita                1.000000         -0.200469
# landOver25k_sqft                 -0.200469          1.000000
# nonRetailLandProptn               0.406583         -0.533828
# riverDummy                       -0.055892         -0.042697
# nitrixOxide_pp10m                 0.420972         -0.516604
# AvgNo.RoomsPerDwelling           -0.219247          0.311991
# ProptnOwnerOccupied               0.352734         -0.569537
# weightedDist                     -0.379670          0.664408
# radialHighwayAccess               0.625505         -0.311948
# propTaxRate_per10k                0.582764         -0.314563
# pupilTeacherRatio                 0.289946         -0.391679
# pctLowerStatus                    0.455621         -0.412995
# medianValue_Ks                   -0.388305          0.360445
#
#                         nonRetailLandProptn  riverDummy  nitrixOxide_pp10m  \
# crimeRatePerCapita                 0.406583   -0.055892           0.420972
# landOver25k_sqft                  -0.533828   -0.042697          -0.516604
# nonRetailLandProptn                1.000000    0.062938           0.763651
# riverDummy                         0.062938    1.000000           0.091203
# nitrixOxide_pp10m                  0.763651    0.091203           1.000000
# AvgNo.RoomsPerDwelling            -0.391676    0.091251          -0.302188
# ProptnOwnerOccupied                0.644779    0.086518           0.731470
# weightedDist                      -0.708027   -0.099176          -0.769230
# radialHighwayAccess                0.595129   -0.007368           0.611441
# propTaxRate_per10k                 0.720760   -0.035587           0.668023
# pupilTeacherRatio                  0.383248   -0.121515           0.188933
# pctLowerStatus                     0.603800   -0.053929           0.590879
# medianValue_Ks                    -0.483725    0.175260          -0.427321
#
#                         AvgNo.RoomsPerDwelling  ProptnOwnerOccupied  \
# crimeRatePerCapita                   -0.219247             0.352734
# landOver25k_sqft                      0.311991            -0.569537
# nonRetailLandProptn                  -0.391676             0.644779
# riverDummy                            0.091251             0.086518
# nitrixOxide_pp10m                    -0.302188             0.731470
# AvgNo.RoomsPerDwelling                1.000000            -0.240265
# ProptnOwnerOccupied                  -0.240265             1.000000
# weightedDist                          0.205246            -0.747881
# radialHighwayAccess                  -0.209847             0.456022
# propTaxRate_per10k                   -0.292048             0.506456
# pupilTeacherRatio                    -0.355501             0.261515
# pctLowerStatus                       -0.613808             0.602339
# medianValue_Ks                        0.695360            -0.376955
#
#                         weightedDist  radialHighwayAccess  propTaxRate_per10k  \
# crimeRatePerCapita         -0.379670             0.625505            0.582764
# landOver25k_sqft            0.664408            -0.311948           -0.314563
# nonRetailLandProptn        -0.708027             0.595129            0.720760
# riverDummy                 -0.099176            -0.007368           -0.035587
# nitrixOxide_pp10m          -0.769230             0.611441            0.668023
# AvgNo.RoomsPerDwelling      0.205246            -0.209847           -0.292048
# ProptnOwnerOccupied        -0.747881             0.456022            0.506456
# weightedDist                1.000000            -0.494588           -0.534432
# radialHighwayAccess        -0.494588             1.000000            0.910228
# propTaxRate_per10k         -0.534432             0.910228            1.000000
# pupilTeacherRatio          -0.232471             0.464741            0.460853
# pctLowerStatus             -0.496996             0.488676            0.543993
# medianValue_Ks              0.249929            -0.381626           -0.468536
#
#                         pupilTeacherRatio  pctLowerStatus  medianValue_Ks
# crimeRatePerCapita               0.289946        0.455621       -0.388305
# landOver25k_sqft                -0.391679       -0.412995        0.360445
# nonRetailLandProptn              0.383248        0.603800       -0.483725
# riverDummy                      -0.121515       -0.053929        0.175260
# nitrixOxide_pp10m                0.188933        0.590879       -0.427321
# AvgNo.RoomsPerDwelling          -0.355501       -0.613808        0.695360
# ProptnOwnerOccupied              0.261515        0.602339       -0.376955
# weightedDist                    -0.232471       -0.496996        0.249929
# radialHighwayAccess              0.464741        0.488676       -0.381626
# propTaxRate_per10k               0.460853        0.543993       -0.468536
# pupilTeacherRatio                1.000000        0.374044       -0.507787
# pctLowerStatus                   0.374044        1.000000       -0.737663
# medianValue_Ks                  -0.507787       -0.737663        1.000000

# %% [markdown]
# ### You are also encouraged to include the interaction of these variables to order two in your model.

# %%
# nonretailLandProptn nitrixOxide_pp10m radialHighwayAccess propTaxRate_per10k pctLowerStatus

# define linear regressions model
multiLinearModel = smf.ols(formula='np.log(crimeRatePerCapita) ~ nitrixOxide_pp10m + nonRetailLandProptn + radialHighwayAccess + propTaxRate_per10k + pctLowerStatus + pctLowerStatus:nitrixOxide_pp10m\
                            + pctLowerStatus:nonRetailLandProptn + pctLowerStatus:radialHighwayAccess \
                            + pctLowerStatus:propTaxRate_per10k + nitrixOxide_pp10m:nonRetailLandProptn \
                            + nitrixOxide_pp10m:radialHighwayAccess + nitrixOxide_pp10m:propTaxRate_per10k \
                            + nonRetailLandProptn:radialHighwayAccess + nonRetailLandProptn:propTaxRate_per10k', data=renamedBostonData)

# %%
multiLinearModelResults = multiLinearModel.fit()
print(multiLinearModelResults.summary())
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     np.log(crimeRatePerCapita)   R-squared:                       0.884
# Model:                                    OLS   Adj. R-squared:                  0.881
# Method:                         Least Squares   F-statistic:                     268.0
# Date:                        Wed, 22 Sep 2021   Prob (F-statistic):          1.92e-219
# Time:                                07:36:10   Log-Likelihood:                -562.06
# No. Observations:                         506   AIC:                             1154.
# Df Residuals:                             491   BIC:                             1218.
# Df Model:                                  14
# Covariance Type:                    nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                 -11.6269      1.390     -8.362      0.000     -14.359      -8.895
# nitrixOxide_pp10m                          16.2836      3.095      5.260      0.000      10.202      22.366
# nonRetailLandProptn                         0.1325      0.072      1.836      0.067      -0.009       0.274
# radialHighwayAccess                         0.1146      0.103      1.107      0.269      -0.089       0.318
# propTaxRate_per10k                          0.0132      0.007      1.995      0.047       0.000       0.026
# pctLowerStatus                              0.0105      0.040      0.261      0.794      -0.069       0.090
# pctLowerStatus:nitrixOxide_pp10m            0.1821      0.078      2.340      0.020       0.029       0.335
# pctLowerStatus:nonRetailLandProptn         -0.0062      0.002     -3.850      0.000      -0.009      -0.003
# pctLowerStatus:radialHighwayAccess          0.0036      0.002      1.754      0.080      -0.000       0.008
# pctLowerStatus:propTaxRate_per10k       -8.591e-05      0.000     -0.664      0.507      -0.000       0.000
# nitrixOxide_pp10m:nonRetailLandProptn      -0.1354      0.126     -1.071      0.285      -0.384       0.113
# nitrixOxide_pp10m:radialHighwayAccess       0.0532      0.234      0.228      0.820      -0.406       0.513
# nitrixOxide_pp10m:propTaxRate_per10k       -0.0281      0.015     -1.830      0.068      -0.058       0.002
# nonRetailLandProptn:radialHighwayAccess    -0.0012      0.003     -0.433      0.665      -0.006       0.004
# nonRetailLandProptn:propTaxRate_per10k      0.0002      0.000      1.583      0.114   -3.93e-05       0.000
# ==============================================================================
# Omnibus:                        3.169   Durbin-Watson:                   0.778
# Prob(Omnibus):                  0.205   Jarque-Bera (JB):                2.947
# Skew:                           0.160   Prob(JB):                        0.229
# Kurtosis:                       3.193   Cond. No.                     1.06e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.06e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### You should produce graphs and data that show that your model satisfies the assumptions of linear regression.
