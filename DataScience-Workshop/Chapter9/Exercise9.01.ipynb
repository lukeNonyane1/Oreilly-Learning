# %% [markdown]
# ## Extracting the Linear Regression Coefficient

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import altair as alt

# %%
file_url = 'https://raw.githubusercontent.com/PacktWorkshops/The-Data-Science-Workshop/master/Chapter09/Dataset/phpYYZ4Qc.csv'

# %%
df = pd.read_csv(file_url)
df.head()
# Out:
#        a1cx      a1cy      a1sx      a1sy     a1rho     a1pop      a2cx  \
# 0  0.413010  0.607442  0.332608  0.406812 -0.151224  1.525222 -0.144368
# 1 -0.602384  0.350618  0.429196  0.414476 -0.124489  4.597991  0.579458
# 2 -0.322881 -0.538491  1.602260  0.039605  0.196023  1.909005 -0.675672
# 3 -0.233570 -0.936451  1.710192  2.179527  0.438461  4.742055 -0.163625
# 4  0.403126  0.313367  0.822382  1.393975  0.253435  9.398630  0.312528
#
#        a2cy      a2sx      a2sy  ...       b2x       b2y  b2call     b2eff  \
# 0  0.852368  0.412397  1.728169  ... -0.776759 -0.783770     8.0  0.603486
# 1  0.651134  0.104394  0.636356  ... -0.002820 -0.080542     2.0  1.125542
# 2  0.963618  0.147458  1.414008  ... -0.952645 -0.571600     5.0  1.280392
# 3 -0.923273  0.597622  0.118409  ... -0.198235 -0.205276     2.0  0.509727
# 4  0.288321  0.431867  0.110369  ...  0.573352  0.315217     2.0  0.622033
#
#         b3x       b3y  b3call     b3eff  mxql       rej
# 0 -0.997118 -0.502138     5.0  1.169388   9.0  0.049118
# 1 -0.983397 -0.107632     5.0  1.186039   7.0  0.242579
# 2  0.771129 -0.665756     5.0  1.024203   6.0  0.000000
# 3 -0.579544  0.480094     6.0  1.568492   7.0  0.469045
# 4 -0.134747  0.669948     3.0  1.295913   9.0  0.000000
#
# [5 rows x 33 columns]

# %%
y = df.pop('rej')

# %%
df.describe()
# Out:
#               a1cx         a1cy         a1sx         a1sy        a1rho  \
# count  8192.000000  8192.000000  8192.000000  8192.000000  8192.000000
# mean     -0.003230    -0.000939     1.011966     1.004934    -0.001786
# std       0.579124     0.577033     1.027579     1.001369     0.288346
# min      -0.999409    -0.999864     0.000191     0.000055    -0.499944
# 25%      -0.499372    -0.500793     0.293154     0.283420    -0.253597
# 50%      -0.013944     0.001390     0.692698     0.690240    -0.001311
# 75%       0.506926     0.494132     1.394602     1.398254     0.246830
# max       0.999881     0.999828    10.303770     8.856675     0.499937
#
#              a1pop         a2cx         a2cy         a2sx         a2sy  ...  \
# count  8192.000000  8192.000000  8192.000000  8192.000000  8192.000000  ...
# mean      3.068520    -0.000240    -0.001100     0.996411     0.993268  ...
# std       3.068512     0.575362     0.577482     0.978954     1.009709  ...
# min       0.000162    -0.999986    -0.999717     0.000114     0.000430  ...
# 25%       0.883641    -0.490687    -0.507070     0.286112     0.282905  ...
# 50%       2.130011     0.000478     0.007756     0.701715     0.688298  ...
# 75%       4.235844     0.502243     0.490494     1.392521     1.363553  ...
# max      27.015529     0.999743     0.999511     7.927502    13.507064  ...
#
#              b1eff          b2x          b2y       b2call        b2eff  \
# count  8192.000000  8192.000000  8192.000000  8192.000000  8192.000000
# mean      1.248389    -0.016438     0.001713     3.994629     1.247177
# std       0.432080     0.579010     0.571700     1.632885     0.430426
# min       0.500110    -0.999677    -0.999622     2.000000     0.500194
# 25%       0.870518    -0.516167    -0.484386     3.000000     0.874773
# 50%       1.251238    -0.011360    -0.001674     4.000000     1.247008
# 75%       1.619040     0.483353     0.496305     5.000000     1.615999
# max       1.999976     0.999404     0.999759     8.000000     1.999761
#
#                b3x          b3y       b3call        b3eff         mxql
# count  8192.000000  8192.000000  8192.000000  8192.000000  8192.000000
# mean      0.000752     0.001569     4.010864     1.242247     7.002930
# std       0.578329     0.579423     1.637225     0.431913     1.421186
# min      -0.999998    -0.999897     2.000000     0.500334     5.000000
# 25%      -0.500204    -0.502221     3.000000     0.869434     6.000000
# 50%       0.004710    -0.004599     4.000000     1.235297     7.000000
# 75%       0.503490     0.510076     5.000000     1.617383     8.000000
# max       0.999774     0.999771     8.000000     1.999838     9.000000
#
# [8 rows x 32 columns]

# %%
# split data into training and test sets with test_size=0.3
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.3, random_state=1)

# %%
# instantiate StandardScaler
scaler = StandardScaler()

# train and standardize training set using scaler using fit_tranform()
X_train = scaler.fit_transform(X_train) # standardizing our features to be between -1 and 1.

# standardize testing set
X_test = scaler.transform(X_test) # standardizing our targets to be between -1 and 1.

# %%
# LinearRegression
lr_model = LinearRegression()

# train model on training set
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# predict the outcomes of training and testing sets using .predict()
preds_train = lr_model.predict(X_train)
preds_test = lr_model.predict(X_test)

# calculate MSE on training set
train_mse = mean_squared_error(y_train, preds_train)
print(train_mse)
# Out:
# 0.007062801218218886

# %%
# calculate MSE on testing set
test_mse = mean_squared_error(y_test, preds_test)
print(test_mse)
# Out:
# 0.006571073840504757

# %% [markdown]
# We also have a low MSE score on the testing set that is very similar to the training one. So, our model is not overfitting.

# %%
# print coefficients of linear regression model
lr_model.coef_
# Out:
# array([-4.94784409e-04, -9.33729668e-04, -2.81877324e-03, -3.29306515e-03,
#         5.93297658e-05,  4.02235021e-02,  1.98044098e-03, -3.39452179e-04,
#        -5.44949336e-03, -4.82500415e-03,  8.22897305e-05,  6.24226133e-02,
#        -2.66390121e-04,  5.69511279e-04, -2.30657474e-03, -2.51428876e-03,
#        -1.31637908e-03,  3.96978126e-02, -1.05127088e-02,  3.02116023e-04,
#        -3.89728413e-04,  3.57359816e-03, -1.43282556e-02, -1.13460794e-03,
#        -1.02515456e-03,  5.50201521e-03, -4.02044201e-03, -1.15164578e-03,
#         2.15908520e-04,  5.59779791e-03, -2.42464365e-03, -1.75240320e-02])

# %%
coef_df = pd.DataFrame()

# %%
coef_df['feature'] = df.columns
coef_df.head()
# Out:
#   feature
# 0    a1cx
# 1    a1cy
# 2    a1sx
# 3    a1sy
# 4   a1rho

# %%
coef_df['coefficient'] = lr_model.coef_
coef_df.head()
# Out:
#   feature  coefficient
# 0    a1cx    -0.000495
# 1    a1cy    -0.000934
# 2    a1sx    -0.002819
# 3    a1sy    -0.003293
# 4   a1rho     0.000059

# %% [markdown]
# From this output, we can see the variables a1sx and a1sy have the lowest value (the biggest negative value) so they are contributing more to the prediction than the three other variables shown here.

# %%
alt.Chart(coef_df).mark_bar().encode(x='coefficient', y='feature')
# Out:
# alt.Chart(...)

# %% [markdown]
# The first three variables impacted the outcome positively (increasing the target variable value). This means as the population grows in any of the three areas, the chance of customer churn increases. On the other hand, the last three features negatively impacted the target variable (decreasing the target variable value): if the maximum length, bank-1 efficiency level, or temperature increases, the risk of customers leaving decreases.
#
# In this exercise, you learned how to extract the coefficients learned by a linear regression model and identified which variables make the biggest contribution to the prediction.
